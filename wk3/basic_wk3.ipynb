# %% [markdown]
# # **Decision Tree (의사결정 나무)**

# %% [markdown]
# <div align="center">
#     <img src="https://images.datacamp.com/image/upload/v1677504957/decision_tree_for_heart_attack_prevention_2140bd762d.png" width=500>
# </div>
#
# Decision Tree는 데이터의 독립변수에 대한 규칙을 순차적으로 적용하면서 분류하는 모델로, 마치 스무고개와 같은 원칙을 가지는 모델이다.

# %% [markdown]
# #### **작동 알고리즘**

# %% [markdown]
# Decision Tree는 최대한 좋은 성능을 내기 위해서 트리의 매 노드마다 특정 클래스가 가지는 공통된 특성을 파악하여 분할할 필요가 있다.<br>
# 따라서 <u>불순도(imputity)</u>, <u>불확실성(uncertainty)</u>를 최소화하는 방향으로 학습을 진행한다.<br>
#
# - **불순도**(imputity)는 특정 클래스가 얼마나 섞여있는지를 나타내는 지표이기에, 데이터가 고르게 섞여있어 분류하기 어려울수록 불순도가 높다고 볼 수 있다.<br>
# - **불확실성**(uncertainty)은 해당 노드에서 샘플의 클래스를 얼마나 예측하기 어려운가를 나타내는 지표이기에, 데이터가 고르게 섞여있어 분류하기 어려울수록 불확실성이 높다고 볼 수 있다.<br>
# - Decision Tree에서 **불순도**(imputity)과 **불확실성**(uncertainty)는 클래스 분포의 혼합 정도를 나타내는 표현으로 거의 같은 의미로 사용된다.<br>
#
# Decision Tree에서는 불순도(imputity)를 수치화한 후, 규칙을 적용하기 전후의 불순도 차를 최대화함으로써 현재 상황에서 <u>정보 획득(information gain)</u>을 최대화하는 규칙을 찾아 노드를 분할한다. 이 규칙을 찾는 과정에서 최종적으로 하나의 독립변수가 선택되게 된다.<br>
# - **정보 획득**(Information Gain)은 부모 노드와 자식 노드 간 불순도의 차이를 의미하며,
# 이는 분할을 통해 불순도가 얼마나 감소했는지를 나타낸다.
# 불순도 감소량이 클수록 해당 분할은 데이터를 더 효율적으로 분류한 것으로 판단되며,
# Decision Tree 알고리즘은 이러한 정보 획득을 최대화하는 방향으로 학습을 진행한다.

# %% [markdown]
# #### **데이터의 불확실성 지표**

# %% [markdown]
# <div align="center">
#     <img src="https://ekamperi.github.io/images/decision_trees/gini_vs_entropy.png" width=500>
# </div>
# 데이터의 불확실성을 나타내는 지표로는 대표적으로 '**엔트로피**(entropy)'와 '**지니계수**(gini index)'가 있다. <br>
# 두 지표는 불확실성을 바라보는 관점과 수식에서의 차이가 있지만, 목적이 완전히 동일하며, 실제로도 대부분 비슷한 분할 결과를 만들어낸다.
#
# - **엔트로피(entropy)**: 엔트로피는 현재 데이터가 얼마나 예측하기 어려운지를 나타내는 불확실성 지표로, 여러 클래스가 고르게 섞여 있을수록 값이 커진다.<br>
#     - $H(X) = -\sum_{i=1}^{n}p(x_i)\, \log \, p(x_i)$
#     - $p(x_i)$ : 범주 $x_i$에 속하는 데이터의 비율
# <br>
#
# - **지니계수(gini index)**: 지니 계수는 데이터가 얼마나 섞여 있는지를 나타내는 불확실성 지표로, 임의의 데이터를 선택했을 때 다른 클래스로 분류될 가능성이 클수록 값이 커진다.<br>
#     - $gini(X) = 1 - \sum_{i=1}^{n}p(x_i)^2$
#     - $p(x_i)$ : 범주 $x_i$에 속하는 데이터의 비율
# <br>
#
# - **정보획득(information gain)** : &nbsp;&nbsp; $gain(x) = uncertainty(T) - uncertainty(T,x)$
#     - $uncertainty$ : 데이터의 불확실성 지표
#     - $T$ : target variable
#     - $x$ : 데이터의 feature 중 하나

# %% [markdown]
# #### **Feature Importance (변수 중요도)**

# %% [markdown]
# - Decision Tree의 각 노드에서 얻은 Infomation Gain을 이용하여 계산
# - 변수 중요도(feature importance) : &nbsp;&nbsp; $ f_{i} = \frac{\sum{1_{x=x_i}*gain}}{\sum{gain}}$
#     - $x$ : 데이터의 feature 중 하나

# %% [markdown]
# #### **Pruning (가지치기)**

# %% [markdown]
# <div align="center">
#     <img src="https://miro.medium.com/v2/resize:fit:1400/1*ElW-ERvIfiV6RSbs74RO_A.png" width="500">
# </div>
# 결정트리(Decision Tree)에 하나의 데이터를 분류하기 위한 가지가 많으면 과적합(overfitting)의 가능성이 존재한다.<br>따라서 결정트리(Decision Tree)의 가지 수를 줄이는 방법을 통해 과적합을 방지할 수 있다.
# - **가지치기(pruning)**: 결정트리(Decision Tree)가 너무 복잡해져서 훈련 데이터에만 맞춰지는 현상(과적합)을 막기 위해, 불필요한 분기(가지)를 제한하거나 제거하는 기법이다.
# - 가지치기(pruning)에는 <u>사전 가지치기(pre-pruning)</u> 방법과 <u>사후 가지치기(post-pruning)</u> 방법이 있지만, 실무에서는 주요 머신러닝 라이브러리에서 파라미터 형태로 쉽게 적용할 수 있는 <u>사전 가지치기(pre-pruning)</u>가 많이 사용된다.
# - Decision Tree의 최대 깊이 수, leaf 노드의 최소 데이터 개수 등을 조절하여 사전 가치치기(pre-pruning)를 할 수 있다.

# %% [markdown]
# DecisionTreeClassifier의 다양한 매개변수 확인: [Decision Tree Classifier 공식 문서](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import classification_report, accuracy_score

# %%
# load data
data = load_iris()

# train, test data split
X_train, X_test, y_train, y_test = train_test_split(data["data"], data["target"],
                                                    test_size=0.2, random_state=42, stratify=data["target"])

print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
# Out:
# (array([0, 1, 2]), array([40, 40, 40]))
# (array([0, 1, 2]), array([10, 10, 10]))

# %% [markdown]
# **Entropy를 활용한 분류**

# %%
# make decision tree
entropy_dt = DecisionTreeClassifier(criterion='entropy', random_state=42)

# fit decision tree
entropy_dt.fit(X_train, y_train)

# test decision tree
y_pred = entropy_dt.predict(X_test)
print(classification_report(y_test, y_pred))
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      0.90      0.90        10
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30
#
# test accuracy : 0.9333333333333333

# %%
# plot decision tree
plt.figure(figsize=(10, 10))
plot_tree(entropy_dt, filled=True, rounded=True, feature_names=data["feature_names"], class_names=data["target_names"])
plt.show()

# %%
# plot feature importance
plt.barh(data["feature_names"], entropy_dt.feature_importances_)
plt.title("feature importance")
plt.show()

# %% [markdown]
# **Gini Index를 활용한 분류**

# %%
# make decision tree
gini_dt = DecisionTreeClassifier(criterion='gini', random_state=42)

# fit decision tree
gini_dt.fit(X_train, y_train)

# test dicision tree
y_pred = gini_dt.predict(X_test)
print(classification_report(y_test, y_pred))
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      0.90      0.90        10
#            2       0.90      0.90      0.90        10
#
#     accuracy                           0.93        30
#    macro avg       0.93      0.93      0.93        30
# weighted avg       0.93      0.93      0.93        30
#
# test accuracy : 0.9333333333333333

# %%
# plot decision tree
plt.figure(figsize=(10, 10))
plot_tree(gini_dt, filled=True, feature_names=data["feature_names"], class_names=data["target_names"])
plt.show()

# %%
# plot feature importance
plt.barh(data["feature_names"], gini_dt.feature_importances_)
plt.title("feature importance")
plt.show()

# %% [markdown]
# **Pruning 이용**

# %%
# make decision tree
pruning_dt = DecisionTreeClassifier(criterion='entropy', splitter='best', max_depth=3, random_state=42)

# fit decision tree
pruning_dt.fit(X_train, y_train)

# test decision tree
y_pred = pruning_dt.predict(X_test)
print(classification_report(y_test, y_pred))
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      0.90      0.95        10
#            2       0.91      1.00      0.95        10
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
#
# test accuracy : 0.9666666666666667

# %%
# plot decision tree
plt.figure(figsize=(10, 10))
plot_tree(pruning_dt, filled=True, feature_names=data["feature_names"], class_names=data["target_names"])
plt.show()

# %%
# plot feature importance
plt.barh(data["feature_names"], pruning_dt.feature_importances_)
plt.title("feature importance")
plt.show()

# %% [markdown]
# # **Model Ensemble**

# %% [markdown]
# <div align="center">
#     <img src="https://oopy.lazyrockets.com/api/v2/notion/image?src=https://s3-us-west-2.amazonaws.com/secure.notion-static.com/a00735fb-c4d9-4928-8548-49601f6c0d93/Untitled.png&blockId=e07977ce-4b7b-42ae-9c3b-ba6b31c57fac" width=500>
# </div>
#
# 머신러닝에서 여러 모델을 결합해 성능을 향상시키는 기법을 **앙상블(Ensemble)** 이라 한다.<br>
# 각 모델은 학습 데이터의 서로 다른 부분이나 특성에 주목하며, 이 과정에서 각기 다른 오류 패턴이나 편향된 판단을 가지게 된다.<br>
# 이러한 모델들을 함께 결합하면, 개별 모델의 오차는 상호 보완되어 감소하고, 보다 안정적이고 일반화 성능이 높은 예측 결과를 얻을 수 있다.

# %% [markdown]
# #### **Model Ensemble 종류**

# %% [markdown]
# <div align="center">
#     <img src ="https://miro.medium.com/v2/resize:fit:1153/1*XzaoQxMf4uLD5DIHz8JwbA.png" width=600>
# </div>
#
# 모델 앙상블의 방법으로는 대표적으로 Voting, Bagging, Boosting이 있다.
# - **Voting** : 서로 다른 알고리즘(ex. Linear Regression, KNN, SVM 등등) 을 가진 모델을 병렬로 결합한다.
#     - Hard Voting : 모델이 예측한 결과값 중 가장 개수가 많은 결과값 선택한다.
#     - Soft Voting : 각각의 모델이 예측한 클래스별 확률을 평균낸 후 가장 높은 확률을 가진 결과값을 선택한다.
#     - Hard Voting(왼쪽 이미지)의 경우 3개의 classifier(1,3,4)가 클래스1로 예측하고, 1개의 classifier(2)가 클래스2로 예측하므로, 다수결로 인해 클래스1로 예측한다.
#     - Soft Voting(오른쪽 이미지)의 경우 클래스 1일 확률은 (0.7+0.2+0.8+0.9)/4 = 0.65이고, 클래스2일 확률은 (0.3+0.8+0.2+0.1)/4 = 0.35 이므로, 클래스1로 예측한다.
#
#
#       <img src ="https://velog.velcdn.com/images%2Fjiselectric%2Fpost%2Fd3eabe8e-b223-4e6d-8a9f-3442f8767d9b%2F%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202021-01-24%2017.42.36.png" width=600>
#
# - **Bagging (Bootstrap Aggregating)** : 서로 같은 알고리즘을 가진 모델을 병렬적으로 결합한다.
#     - 훈련 데이터로부터 랜덤하게 복원추출하여 동일한 사이즈의 데이터셋을 여러개 만든다. (bootstrap)
#     - 각각의 데이터셋으로 동일한 알고리즘을 가진 각각의 모델을 학습시킨 후 voting 방식으로 결과값을 선택한다. (aggregating)
#     - 높은 분산(variance)을 낮추는데 유용하다. (과적합을 방지하는데 유용하다.)
#     - 대표적인 알고리즘으로는 <u>랜덤 포레스트(Random Forest)</u> 알고리즘이 있다.
#
# - **Boosting** : 여러 개의 모델을 순차적으로 결합한다.
#     - 현재 모델에서 틀린 결과값을 낸 데이터에 대해 큰 가중치를 부여한다.
#     - 가중치가 부여된 데이터로 다음 모델이 예측함으로써 오류를 개선해나간다.
#     - 각 모델들의 예측값을 가중합하여 결과값을 선택한다.
#     - 높은 bias를 낮추는데 유용하다. (과소적합을 해결하는데 유용하다.)
#     - 대표적인 알고리즘으로 <u>Adaboost, Gradient Boosting, XGBoost, LightGBM</u> 등이 있다.

# %% [markdown]
# # **Random Forest**

# %% [markdown]
# <div align="center">
#     <img src="https://miro.medium.com/v2/resize:fit:1400/1*jE1Cb1Dc_p9WEOPMkC95WQ.png" width=500>
# </div>
# Random Forest는 Bagging 기법을 Decision Tree에 적용한 대표적인 앙상블(Ensemble) 모델이다. 여러 개의 Decision Tree를 서로 다른 학습 데이터(bootstrap 샘플)로 학습시키고, 각 트리의 예측 결과를 다수결 또는 평균 방식으로 결합해 최종 예측을 수행한다. 이를 통해 하나의 Decision Tree가 가지는 과적합 문제를 해결하고, 보다 안정적인 예측 성능을 얻을 수 있다.

# %% [markdown]
# #### **작동 알고리즘**

# %% [markdown]
# 여러 개의 Decision Tree를 만들고 예측한 값들로 voting 방식을 이용하여 결과값을 도출해낸다.<br>
# 각각의 Decision Tree를 만드는 방법은 다음과 같다.
# - Tree를 훈련시킬 데이터를 전체 데이터셋에서 복원추출(bootstrap) 방법으로 샘플링한다.
# - 샘플링된 데이터를 이용하여 Decision Tree를 구축하는데, 각 노드별로 규칙을 찾을 때 전체 변수에서 랜덤으로 샘플링된 변수들만 이용한다.

# %% [markdown]
# RandomForestClassifier의 다양한 인자 확인 : [Random Forest Classifier 공식 문서](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
# load data
data = load_breast_cancer()

# train, test data split
X_train, X_test, y_train, y_test = train_test_split(data["data"], data["target"],
                                                    test_size=0.2, random_state=42, stratify=data["target"])

print(np.unique(y_train, return_counts=True))
print(np.unique(y_test, return_counts=True))
# Out:
# (array([0, 1]), array([170, 285]))
# (array([0, 1]), array([42, 72]))

# %%
# make random forest
rf = RandomForestClassifier(bootstrap=True,             # 부트스트랩 샘플링 사용 여부
                            class_weight=None,          # 클래스별 가중치
                            criterion='gini',           # 불순도 측정 방법
                            max_depth=None,             # 트리의 최대 깊이
                            max_features='sqrt',        # 최적의 분할을 위해 고려할 최대 특성 수
                            n_estimators=100,           # 생성할 트리의 개수
                            oob_score=True,             # out of bag score (훈련에 사용되지 않은 샘플들에 대한 점수)
                            n_jobs=-1,                  # 병렬 처리할 작업 수
                            min_impurity_decrease=0.0,  # 트리를 분기하기 위해 필요한 최소 불순도 감소
                            random_state=42)

# fit random forest
rf.fit(X_train, y_train)

# test random forest
y_pred = rf.predict(X_test)
print(classification_report(y_test, y_pred))
print(f'out of bag score: {rf.oob_score_}')
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        42
#            1       0.96      0.97      0.97        72
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# out of bag score: 0.9538461538461539
# test accuracy : 0.956140350877193

# %%
# plot feature importance
plt.barh(data["feature_names"], rf.feature_importances_)    # Random Forest의 feature importance는
plt.title("feature importance")                             # 각 Decision Tree의 feature importance 평균
plt.show()

# %% [markdown]
# **Decision Tree와 비교**

# %%
# make decision tree
dt = DecisionTreeClassifier(criterion='gini', random_state=42)

# fit decision tree
dt.fit(X_train, y_train)

# test decision tree
y_pred = dt.predict(X_test)
print(classification_report(y_test, y_pred))
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.93      0.89        42
#            1       0.96      0.90      0.93        72
#
#     accuracy                           0.91       114
#    macro avg       0.90      0.92      0.91       114
# weighted avg       0.92      0.91      0.91       114
#
# test accuracy : 0.9122807017543859

# %% [markdown]
# # **Boosting**

# %% [markdown]
# <div align="center">
#     <img src="https://jinsu-l.github.io/assets/post_images/image-20191217222322387.png" width=500>
# </div>
# Boosting은 현재 모델 $A$가 예측했을 때의 오답에 대해 가중치를 더 주고, 가중치가 부여된 데이터를 다음 모델 $B$가 예측하고, 이를 반복하는 기법이다.
#
# 이 때, $A$와 $B$를 weak learner라고 한다. 즉, weak learner 여러 개를 더하여 strong learner를 만드는 것이 Boosting이라 할 수 있다.<br>
# 대표적인 Boosting 알고리즘 종류에는 **AdaBoost, Gradient Boosting, XGBoost, LightGBM** 등이 있다.

# %% [markdown]
# ### **AdaBoost(Adaptive Boosting)**
# 가장 기본적이고 초기 형태의 Boosting 알고리즘으로써, 이전 모델의 틀린 데이터(weak learner)에 더 큰 가중치를 주어 오차를 줄이는 방식으로 다음 모델을 학습시킨다. 최종 예측은 모델마다 부여된 가중치를 곱한 뒤 합산하여 결정된다. AdaBoost 방식은 이상치나 노이즈가 많은 데이터에서는 틀린 샘플에 과도하게 집중하게 되어 성능이 불안정해질 수 있다는 단점이 있다.
# <br>
# AdaBoostClassifier의 다양한 인자 : [AdaBoost Classifier 공식 문서](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

# %%
# make AdaBoost
ab = AdaBoostClassifier(n_estimators=100,     # 트리의 개수 또는 부스팅 단계 수
                        learning_rate=1,      # 부여되는 가중치 스케일 조절
                        random_state=42)

# fit AdaBoost
ab.fit(X_train, y_train)

# test AdaBoost
y_pred = ab.predict(X_test)
print(classification_report(y_test, y_pred))
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.94        42
#            1       0.95      0.99      0.97        72
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# test accuracy : 0.956140350877193

# %% [markdown]
# ### **Gradient Boosting**
# Gradient Boosting은 '틀렸는지 여부에 따라 가중치를 부여하는' AdaBoost와는 다르게, '얼마나 틀렸는지(오차의 크기)'를 기준으로 모델을 개선하는 Boosting 방식이다. 즉, 오차의 크기를 계산하고, 틀린 방향을 보정하는 트리를 계속 더해가는 방식이다. 이때 새로 학습되는 결정트리는 최종 값을 직접 예측하는 것이 아니라, 현재 모델이 어떤 방향으로, 얼마나 틀렸는지를 보정하는 역할을 한다. Gradient Boosting은 예측 성능이 뛰어나지만, 학습이 순차적으로 이루어져 속도가 느리고, 과적합 및 하이퍼파라미터 설정에 민감하다는 단점이 있다.
# <br>
# GradientBoostingClassifier의 다양한 인자 확인 : [Gradinent Boosting Classifier 공식 문서](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.GradientBoostingClassifier.html)

# %%
# make gradient boosting
gb = GradientBoostingClassifier(n_estimators=100,     # 트리의 개수 또는 부스팅 단계 수
                                loss="log_loss",      # 최적화할 때 사용하는 손실함수
                                subsample=0.9,        # 각 트리별로 랜덤으로 샘플링되는 데이터의 비율
                                learning_rate=0.1,    # 각 트리의 기여도 조절
                                random_state=42)

# fit gradient boosting
gb.fit(X_train, y_train)

# test gradient boosting
y_pred = gb.predict(X_test)
print(classification_report(y_test, y_pred))
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.94        42
#            1       0.95      0.99      0.97        72
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# test accuracy : 0.956140350877193

# %% [markdown]
# ### **XGBoost(Extreme Gradient Boosting)**
# Gradient Boosting의 단점을 보완하기 위해 만들어진 알고리즘으로, Gradient Boosting과 유사하나, 병렬처리를 통해 속도를 높이고, 규제(Regularization)를 통해 과적합을 방지함으로써 더 빠르고 안정적으로 동작하는 개선된 알고리즘이다. 또한 트리를 만들때 균형 트리 분할(Level Wise)  방식으로 성장시켜 구조적 안정성을 유지한다.<br>
#
#
# XGBClassifier의 다양한 인자 확인 : [XGBoost 공식 문서](https://xgboost.readthedocs.io/en/stable/python/python_api.html)

# %%
# make XGBoost
xgb = XGBClassifier(n_estimators=100,     # 트리의 개수 또는 부스팅 단계 수
                    learning_rate=0.3,    # 각 트리의 기여도 조절
                    subsample=0.9,        # 각 트리별로 랜덤으로 샘플링되는 데이터의 비율
                    random_state=42)

# fit XGBoost
xgb.fit(X_train, y_train)

# test XGBoost
y_pred = xgb.predict(X_test)
print(classification_report(y_test, y_pred))
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.90      0.94        42
#            1       0.95      0.99      0.97        72
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
#
# test accuracy : 0.956140350877193

# %%
# plot importance
plt.barh(data["feature_names"], xgb.feature_importances_)
plt.title("feature importance")
plt.show()

# %% [markdown]
# ### **LightGBM(Light Gradient Boosting Machine)**
# XGBoost의 단점을 보완하기 위해 만들어진 알고리즘으로, XGBoost와 유사하나, 트리를 분할하는 방식이 다르다. XGBoost는 균형 트리 분할(Level Wise) 방식이고, LightGBM은 리프 중심 트리 분할(Leaf Wise) 방식을 사용한다. 리프 중심 트리 분할(Leaf Wise) 방식은 트리를 층 단위로 균형 있게 키우는 대신 현재 오차 감소 효과가 가장 큰 리프 노드 하나만 선택해 집중적으로 분할하는 방식이다. 즉, 최대손실 값을 가지도록 노드를 분할하기 때문에, 균형 트리 분할 방식보다 더 깊으면서 비대칭적인 트리가 생성된다.<br>
# <div align="center">
#     <img src="https://media.geeksforgeeks.org/wp-content/uploads/20250519151930194905/level_wise_tree_growth_1.webp" width=500>
# </div>
# <br>
# LGBMClassifier의 다양한 인자 확인 : [LGBM Classifier 공식 문서](https://lightgbm.readthedocs.io/en/latest/pythonapi/lightgbm.LGBMClassifier.html)

# %%
# make LightGBM
lgbm = LGBMClassifier(n_estimators=100,     # 트리의 개수 또는 부스팅 단계 수
                      learning_rate=0.1,    # 각 트리의 기여도 조절
                      subsample=0.9,        # 각 트리별로 랜덤으로 샘플링되는 데이터의 비율
                      verbose=-1,
                      random_state=42)

# fit LightGBM
lgbm.fit(X_train, y_train)

# test LightGBM
y_pred = lgbm.predict(X_test)
print(classification_report(y_test, y_pred))
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95        42
#            1       0.96      0.99      0.97        72
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114
#
# test accuracy : 0.9649122807017544
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMClassifier was fitted with feature names
#   warnings.warn(

# %%
# plot feature importance
plt.barh(data["feature_names"], lgbm.feature_importances_/sum(lgbm.feature_importances_))
plt.title("feature importance")
plt.show()

# %% [markdown]
# # **K-fold Cross Validation**

# %% [markdown]
# **검증(Validation) 데이터** 란, 모델을 학습시키는 데 직접 사용하지 않고, 학습된 모델이 새로운 데이터에도 잘 동작하는지를 확인하기 위해 사용하는 데이터이다. 모델의 성능을 평가할 때 학습에 사용한 데이터를 그대로 사용하면 실제 성능보다 높게 평가될 수 있으므로, 데이터는 일반적으로 학습(train), 검증(validation), 테스트(test) 데이터로 나누어 사용한다. 학습 단계에서는 검증(validation) 데이터를 통해 모델이 단순히 학습 데이터를 외운 것이 아니라, 처음보는 데이터에서도 일반적인 패턴을 잘 학습했는지를 평가할 수 있다.<br>
# <div align="center">
#     <img src="https://miro.medium.com/v2/resize:fit:725/1*R5fZ1LkqhzfqPAR9-UGPIQ.png" width=500>
# </div>
#
# **K-fold Cross Validation** 은 학습 단계에서 사용되는 데이터를 K개의 fold로 나눈 뒤, K−1개의 fold를 학습에 사용하고 나머지 1개의 fold를 validation 데이터로 사용하여 이 과정을 K번 반복하는 방법이다.
#
# 각 fold에서 계산된 validation score를 평균내어 모델의 성능을 평가하며, 이 값은 모델이 학습에 사용되지 않은 데이터에서 얼마나 잘 예측하는지를 나타낸다. validation score가 가장 높은 하이퍼파라미터 조합을 선택한 후, 전체 학습 데이터를 사용해 모델을 다시 학습시키고 최종적으로 test 데이터를 통해 성능을 평가한다.

# %% [markdown]
# #### **사용 이유 및 장단점**

# %% [markdown]
# - 기존 train/validation/test 로 나누던 데이터를 train/test로 나누다 보니, 모델을 훈련시켰을 때 정확도가 더 높아진다.
# - 적은 데이터셋을 가지고 있을 때 유용하다.
# - 모델을 훈련시키고 검증하기를 K번 반복해야 하다 보니 시간이 오래 걸린다.

# %%
from sklearn.model_selection import StratifiedKFold

fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
scores = []

for i, (train_index, val_index) in enumerate(fold.split(X_train, y_train)):
    X_, X_val = X_train[train_index], X_train[val_index]
    y_, y_val = y_train[train_index], y_train[val_index]

    gb = GradientBoostingClassifier(n_estimators=100,
                                    subsample=0.9,
                                    learning_rate=0.1,
                                    random_state=42)
    gb.fit(X_, y_)
    y_pred = gb.predict(X_val)
    acc = accuracy_score(y_val, y_pred)
    scores.append(acc)
    print(f"fold {i+1} accuracy: {acc}")

print(f"validation accuracy (mean): {np.mean(scores)}")
# Out:
# fold 1 accuracy: 0.967032967032967
# fold 2 accuracy: 0.9560439560439561
# fold 3 accuracy: 0.945054945054945
# fold 4 accuracy: 0.945054945054945
# fold 5 accuracy: 0.989010989010989
# validation accuracy (mean): 0.9604395604395604

# %% [markdown]
# # **Grid Search & Random Search**

# %% [markdown]
# <img src="https://www.yourdatateacher.com/wp-content/uploads/2021/03/image-6.png" width=400>
#
# Grid Search는 머신러닝 모델에서 최적의 하이퍼파라미터를 찾기 위한 탐색 방법 중 하나이다.<br>
# 각 하이퍼파라미터에 대해 탐색하고자 하는 여러 값을 지정한 후 그 모든 조합에 대해 모델을 훈련시키고 검증한다.<br>
# 모델 검증에서 가장 좋은 결과를 얻은 하이퍼파라미터 조합을 최종적으로 선택한다.<br>

# %% [markdown]
# <img src="https://attachments.datarian.io/production-1de2a252-a7cf-4eda-af92-800ce37fab3f-9FaeSamyKJwmuNU3qdZOdNgtUKU2tfDJCIKbIzOocuU.png" width=500>
#
# Grid Search는 모든 조합을 탐색하기 때문에 탐색 공간이 넓어질수록 계산 비용이 커지는 단점이 있다.<br>
# 이러한 단점을 극복하기 위해서, 무작위로 선택된 하이퍼파라미터 값들을 사용하여 탐색하는 방법인 Random Search도 있다.<br>
# 제한된 계산 자원 환경에서는 Random Search가 Grid Search보다 효율적으로 하이퍼파라미터 조합을 탐색할 수 있다.

# %% [markdown]
# **Grid Search**

# %%
from sklearn.model_selection import GridSearchCV

# setting params
xgb_params = {
    'n_estimators': [50, 100, 150, 200],
    'max_depth': [1, 3, 5, 7],
    'learning_rate': [0.025, 0.05, 0.075, 0.1],
    'reg_lambda': [0.1, 0.5, 1, 2]
}

# grid search
grid_tree = GridSearchCV(xgb, param_grid=xgb_params,
                         cv=5, refit=True, verbose=1)     # cv는 k-fold cross validaion의 k를 의미함
grid_tree.fit(X_train, y_train)

print(f"Best parameters: {grid_tree.best_params_}")
print(f"Best cross-validation score: {grid_tree.best_score_}")

# test best case
best_estimator = grid_tree.best_estimator_
y_pred = best_estimator.predict(X_test)
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
# Fitting 5 folds for each of 256 candidates, totalling 1280 fits
# Best parameters: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200, 'reg_lambda': 1}
# Best cross-validation score: 0.9802197802197803
# test accuracy : 0.956140350877193

# %% [markdown]
# **Random Search**

# %%
from sklearn.model_selection import RandomizedSearchCV

# setting params
xgb_params = {
    'n_estimators': [50, 100, 150, 200, 250],
    'max_depth': [1, 3, 5, 7, 9],
    'learning_rate': [0.025, 0.05, 0.075, 0.1, 0.125],
    'reg_lambda': [0.1, 0.5, 1, 1.5, 2]
}

# grid search
random_tree = RandomizedSearchCV(xgb, param_distributions=xgb_params,                         # n_iter는 샘플링되는 하이퍼파라미터 조합의 수를 의미함
                                 cv=5, n_iter=20, refit=True, verbose=1, random_state=42)     # cv는 k-fold cross validaion의 k를 의미함
random_tree.fit(X_train, y_train)

print(f"Best parameters: {random_tree.best_params_}")
print(f"Best cross-validation score: {random_tree.best_score_}")

# test best case
best_estimator = random_tree.best_estimator_
y_pred = best_estimator.predict(X_test)
print(f"test accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# Best parameters: {'reg_lambda': 1, 'n_estimators': 150, 'max_depth': 7, 'learning_rate': 0.05}
# Best cross-validation score: 0.9758241758241759
# test accuracy : 0.9473684210526315
